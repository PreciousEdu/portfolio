# %% [markdown]
# # Automatic File Sorter

# %%
import os, shutil

# %%
path = r"C:/Users/USER/OneDrive/Practice Files/"

# %%
file_names = os.listdir(path)
print (os.listdir(path))
# Out:
# ['Assignment.docx', 'Data copy.xlsx', 'Documents', 'Excel Files', 'Invoice.txt', 'Notes.docx', 'passport.docx', 'presentation.xlsx', 'Resume.txt', 'Text Files']

# %%
folder_names = ['Documents', 'Text Files', 'Excel Files'] 

for loop in range(0, len(folder_names)):
    if not os.path.exists(path + folder_names[loop]):
        #print(path + folder_names[loop])
        os.makedirs((path + folder_names[loop]))

for file in file_names:
    if ".docx" in file and not os.path.exists(path + "Documents/" + file):
        shutil.move(path + file, path + "Documents/" + file)
    elif ".xlsx" in file and not os.path.exists(path + "Excel Files/" + file):
        shutil.move(path + file, path + "Excel Files/" + file)
    elif ".txt" in file and not os.path.exists(path + "Text Files/" + file):
        shutil.move(path + file, path + "Text Files/" + file)
